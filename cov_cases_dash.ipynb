# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas

# %%
if 'data' not in pn.state.cache.keys():
    df = pd.read_csv('https://raw.githubusercontent.com/WillBallentine/cov_dashboard/main/United_States_COVID-19_Cases_and_Deaths_by_State_over_Time_-_ARCHIVED.csv')
    pn.state.cache['data'] = df.copy()
    
else:
    df = pn.state.cache['data']

# %%
df
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0          03/11/2021    KS     297229    241035.0     56194.0         0
# 1          12/01/2021    ND     163565    135705.0     27860.0       589
# 2          01/02/2022    AS         11         NaN         NaN         0
# 3          11/22/2021    AL     841461    620483.0    220978.0       703
# 4          05/30/2022    AK     251425         NaN         NaN         0
# ...               ...   ...        ...         ...         ...       ...
# 60055      02/09/2021    TX    2504556         NaN         NaN     13329
# 60056      11/20/2020    FL     913561         NaN         NaN      8217
# 60057      08/17/2020    NM      23500         NaN         NaN        92
# 60058      06/17/2020    MS      24223     24038.0       185.0       521
# 60059      05/07/2022    MA    1779829   1638144.0    141685.0         0
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
df = df.fillna(0)

# %%
idf = df.interactive()

# %%
#Define panel widgets
state_select = pn.widgets.RadioBoxGroup(name="State Select", options=['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY',], inline=False)
state_select
# Out:
# RadioBoxGroup(name='State Select', options=['AL', 'AK', 'AZ', ...], value='AL')

# %%
tot_case_pipeline = (idf[(idf.state) == state_select])

# %%
tot_case_pipeline
# Out:
# <div id='1346'>
#   <div class="bk-root" id="fa5f3386-9be0-4a1b-b818-0f9f893232c3" data-root-id="1346"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
tot_plot = tot_case_pipeline.hvplot(kind='bar', x='submission_date', by='state', y='tot_cases', title="Total cases by state")
tot_plot
# Out:
# <div id='1820'>
#   <div class="bk-root" id="72f59f3c-e8da-486b-9d5c-b09847773556" data-root-id="1820"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
deaths_pipeline = (idf[(idf.state) == state_select])

# %%
deaths_pipeline
# Out:
# <div id='1511'>
#   <div class="bk-root" id="e00af93c-fa6d-42f5-b8ac-a51ddd861a2b" data-root-id="1511"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
deaths_scatterplot = deaths_pipeline.hvplot(x='submission_date', y='tot_death', by='state', size=80, kind="scatter", scale=0.09, legend=False, height = 500, width=500)
deaths_scatterplot
# Out:
# <div id='2397'>
#   <div class="bk-root" id="db26af4d-7e17-44d4-8f16-7baf944eb6cf" data-root-id="2397"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='Covid Cases by State', 
    sidebar=[pn.pane.Markdown("# Covid-19 Cases by State Reports"), 
             pn.pane.Markdown("#### Covid, while largely under conrol, had a massive impact on our States over the last three years."), 
             pn.pane.PNG('covid.png', width=200, height=100),
             pn.pane.Markdown("## Select State"),   
             state_select],
    main=[pn.Row(pn.Column(
                           tot_plot.panel(width=700), margin=(0,25)), 
                 deaths_scatterplot.panel(width=500)), 
],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()
template.servable();
